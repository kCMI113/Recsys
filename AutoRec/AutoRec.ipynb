# %%
import math
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ## Data
# - [ml-latest-small](https://grouplens.org/datasets/movielens/)

# %%
raw_data = pd.read_csv("../data/ml-latest-small/ratings.csv")

item2idx, idx2item = {}, {}
user2idx, idx2user = {}, {}
id2title = {}

for idx, user_id in enumerate(np.unique(raw_data["userId"])):
    user2idx[user_id] = idx
    idx2user[idx] = user_id
for idx, item_id in enumerate(np.unique(raw_data["movieId"])):
    item2idx[item_id] = idx
    idx2item[idx] = item_id

# make index data
index_data = raw_data.copy()
index_data["userId"] = raw_data["userId"].apply(lambda idx:user2idx[idx])
index_data["movieId"] = raw_data["movieId"].apply(lambda idx:item2idx[idx])

n_user = np.unique(raw_data["userId"]).shape[0]
n_item = np.unique(raw_data["movieId"]).shape[0]

# %%
print(n_user, n_item)
# Out:
# 610 9724

# %%
class MovieLensDataset(Dataset):
    def __init__(self, data, n_item, n_user, IsItem:bool=True):
        self.data = data
        self.IsItem = IsItem
        self.i_rating_matrix = np.zeros((n_item, n_user))
        self.u_rating_matrix = np.zeros((n_user, n_item))

        self.__make_rating_mat__()

    def __make_rating_mat__(self):
        for user, item, rating in zip(self.data.userId, self.data.movieId, self.data.rating):
            self.i_rating_matrix[item][user] = rating
            self.u_rating_matrix[user][item] = rating

    def __len__(self):
        if self.IsItem:
            return len(self.i_rating_matrix)
        return len(self.u_rating_matrix)

    def __getitem__(self, index):
        if self.IsItem:
            return torch.tensor(self.i_rating_matrix[index]).float()
        return torch.tensor(self.u_rating_matrix[index]).float()

# %% [markdown]
# ## Model
# - I-AutoRec -> (item, user) rating matrix를 입력으로 줌
# - U-AutoRec -> (user, item) rating matrix를 입력으로 줌

# %%
class AutoRec(nn.Module):
    def __init__(self, n_hidden, n_input, dropout_rate, custom:bool=False):
        super(AutoRec, self).__init__()
        self.custom = custom

        self.encoder = nn.Linear(n_input, n_hidden)
        self.hidden_enc = nn.Linear(n_hidden, n_hidden//2)
        self.b1 = nn.Parameter(torch.ones(n_hidden))
        self.sigmoid = nn.Sigmoid()

        self.hidden_dec = nn.Linear(n_hidden//2, n_hidden)
        self.decoder = nn.Linear(n_hidden, n_input)
        self.b2 = nn.Parameter(torch.ones(n_input))
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, mat):
        if self.custom:
            hidden = self.dropout(self.hidden_enc(self.sigmoid(self.encoder(mat) + self.b1)))
            out = self.decoder(self.sigmoid(self.hidden_dec(hidden))) + self.b2
        else:
            hidden = self.dropout(self.sigmoid(self.encoder(mat) + self.b1))
            out = self.decoder(hidden) + self.b2

        return out

# %% [markdown]
# ## Train

# %%
def train(model, dataloader, optimizer, criterion, device):
    model.train()
    total_loss = 0

    for row in dataloader:
        row = row.to(device)
        out = model(row)

        non_mask = row != 0

        loss = criterion(out[non_mask], row[non_mask])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss/len(dataloader)

def eval(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0


    with torch.no_grad():
        for row in dataloader:
            row = row.to(device)
            non_mask = row != 0

            out = model(row)
            
            total_loss += criterion(out[non_mask], row[non_mask]).item()

    return total_loss/len(dataloader)

# %%
torch.manual_seed(42)
np.random.seed(42)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
n_epochs = 100
batch_size = 256
n_hidden = 128
lr = 0.005

# %%
train_data, test_data = train_test_split(index_data, train_size=0.9)

train_dataset = MovieLensDataset(train_data, n_item, n_user, IsItem=True)  # u-AutoRec : IsItem=False, i-AutoRec : IsItem=True
test_dataset = MovieLensDataset(test_data, n_item, n_user, IsItem=True)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

# %%
model = AutoRec(n_hidden, n_user, 0.5, custom=False) # n_input을 u-AutoRec : n_item, i-AutoRec : n_user
criterion = nn.MSELoss()
optimizer = Adam(model.parameters(), lr=lr)

# %%
all_train_loss = []
all_valid_loss = []

for epoch in range(1, n_epochs+1):
    train_loss = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss = eval(model, test_dataloader, criterion, device)

    all_train_loss.append(train_loss)
    all_valid_loss.append(valid_loss)

    print(f'EPOCH : {epoch:2} | Train Loss : {train_loss:.6f} | Valid Loss : {valid_loss:.6f}')
# Out:
# EPOCH :  1 | Train Loss : 1.699419 | Valid Loss : 1.556843
# EPOCH :  2 | Train Loss : 1.216042 | Valid Loss : 1.403372
# EPOCH :  3 | Train Loss : 1.123337 | Valid Loss : 1.270255
# EPOCH :  4 | Train Loss : 0.992500 | Valid Loss : 1.182619
# EPOCH :  5 | Train Loss : 0.948138 | Valid Loss : 1.142816
# EPOCH :  6 | Train Loss : 0.901724 | Valid Loss : 1.000400
# EPOCH :  7 | Train Loss : 0.838633 | Valid Loss : 0.915078
# EPOCH :  8 | Train Loss : 0.816193 | Valid Loss : 0.884831
# EPOCH :  9 | Train Loss : 0.784483 | Valid Loss : 0.874956
# EPOCH : 10 | Train Loss : 0.783273 | Valid Loss : 0.847794
# EPOCH : 11 | Train Loss : 0.768034 | Valid Loss : 0.804214
# EPOCH : 12 | Train Loss : 0.722806 | Valid Loss : 0.752760
# EPOCH : 13 | Train Loss : 0.693242 | Valid Loss : 0.765695
# EPOCH : 14 | Train Loss : 0.682633 | Valid Loss : 0.761364
# EPOCH : 15 | Train Loss : 0.689780 | Valid Loss : 0.725351
# EPOCH : 16 | Train Loss : 0.671442 | Valid Loss : 0.715867
# EPOCH : 17 | Train Loss : 0.651141 | Valid Loss : 0.692044
# EPOCH : 18 | Train Loss : 0.612066 | Valid Loss : 0.714823
# EPOCH : 19 | Train Loss : 0.615881 | Valid Loss : 0.659275
# EPOCH : 20 | Train Loss : 0.587246 | Valid Loss : 0.638289
# EPOCH : 21 | Train Loss : 0.585683 | Valid Loss : 0.666693
# EPOCH : 22 | Train Loss : 0.568797 | Valid Loss : 0.626742
# EPOCH : 23 | Train Loss : 0.562397 | Valid Loss : 0.630873
# EPOCH : 24 | Train Loss : 0.539067 | Valid Loss : 0.589962
# EPOCH : 25 | Train Loss : 0.521360 | Valid Loss : 0.593792
# EPOCH : 26 | Train Loss : 0.513422 | Valid Loss : 0.574564
# EPOCH : 27 | Train Loss : 0.510835 | Valid Loss : 0.591129
# EPOCH : 28 | Train Loss : 0.508035 | Valid Loss : 0.580067
# EPOCH : 29 | Train Loss : 0.511533 | Valid Loss : 0.579111
# EPOCH : 30 | Train Loss : 0.511895 | Valid Loss : 0.583033
# EPOCH : 31 | Train Loss : 0.495692 | Valid Loss : 0.549667
# EPOCH : 32 | Train Loss : 0.497154 | Valid Loss : 0.570106
# EPOCH : 33 | Train Loss : 0.478071 | Valid Loss : 0.557990
# EPOCH : 34 | Train Loss : 0.470755 | Valid Loss : 0.548670
# EPOCH : 35 | Train Loss : 0.465266 | Valid Loss : 0.533373
# EPOCH : 36 | Train Loss : 0.459820 | Valid Loss : 0.547503
# EPOCH : 37 | Train Loss : 0.454746 | Valid Loss : 0.538775
# EPOCH : 38 | Train Loss : 0.453765 | Valid Loss : 0.548326
# EPOCH : 39 | Train Loss : 0.443778 | Valid Loss : 0.533594
# EPOCH : 40 | Train Loss : 0.438421 | Valid Loss : 0.532432
# EPOCH : 41 | Train Loss : 0.436460 | Valid Loss : 0.519752
# EPOCH : 42 | Train Loss : 0.432447 | Valid Loss : 0.526637
# EPOCH : 43 | Train Loss : 0.435641 | Valid Loss : 0.531634
# EPOCH : 44 | Train Loss : 0.433933 | Valid Loss : 0.528524
# EPOCH : 45 | Train Loss : 0.441642 | Valid Loss : 0.543753
# EPOCH : 46 | Train Loss : 0.430952 | Valid Loss : 0.519210
# EPOCH : 47 | Train Loss : 0.425412 | Valid Loss : 0.538722
# EPOCH : 48 | Train Loss : 0.422782 | Valid Loss : 0.512066
# EPOCH : 49 | Train Loss : 0.414388 | Valid Loss : 0.515874
# EPOCH : 50 | Train Loss : 0.416589 | Valid Loss : 0.527579
# EPOCH : 51 | Train Loss : 0.413274 | Valid Loss : 0.512171
# EPOCH : 52 | Train Loss : 0.402382 | Valid Loss : 0.512949
# EPOCH : 53 | Train Loss : 0.403086 | Valid Loss : 0.502866
# EPOCH : 54 | Train Loss : 0.399056 | Valid Loss : 0.527307
# EPOCH : 55 | Train Loss : 0.399442 | Valid Loss : 0.501891
# EPOCH : 56 | Train Loss : 0.396718 | Valid Loss : 0.511484
# EPOCH : 57 | Train Loss : 0.403952 | Valid Loss : 0.506653
# EPOCH : 58 | Train Loss : 0.403437 | Valid Loss : 0.518461
# EPOCH : 59 | Train Loss : 0.400740 | Valid Loss : 0.521796
# EPOCH : 60 | Train Loss : 0.396543 | Valid Loss : 0.515317
# EPOCH : 61 | Train Loss : 0.384328 | Valid Loss : 0.512071
# EPOCH : 62 | Train Loss : 0.392533 | Valid Loss : 0.510220
# EPOCH : 63 | Train Loss : 0.380959 | Valid Loss : 0.506023
# EPOCH : 64 | Train Loss : 0.379574 | Valid Loss : 0.501176
# EPOCH : 65 | Train Loss : 0.377785 | Valid Loss : 0.507091
# EPOCH : 66 | Train Loss : 0.376112 | Valid Loss : 0.503515
# EPOCH : 67 | Train Loss : 0.373470 | Valid Loss : 0.504274
# EPOCH : 68 | Train Loss : 0.371895 | Valid Loss : 0.503478
# EPOCH : 69 | Train Loss : 0.366621 | Valid Loss : 0.488228
# EPOCH : 70 | Train Loss : 0.365428 | Valid Loss : 0.497341
# EPOCH : 71 | Train Loss : 0.364673 | Valid Loss : 0.498046
# EPOCH : 72 | Train Loss : 0.360613 | Valid Loss : 0.499544
# EPOCH : 73 | Train Loss : 0.360573 | Valid Loss : 0.489603
# EPOCH : 74 | Train Loss : 0.361054 | Valid Loss : 0.500971
# EPOCH : 75 | Train Loss : 0.362497 | Valid Loss : 0.492061
# EPOCH : 76 | Train Loss : 0.356685 | Valid Loss : 0.503362
# EPOCH : 77 | Train Loss : 0.355907 | Valid Loss : 0.498203
# EPOCH : 78 | Train Loss : 0.355300 | Valid Loss : 0.504203
# EPOCH : 79 | Train Loss : 0.356538 | Valid Loss : 0.493285
# EPOCH : 80 | Train Loss : 0.350028 | Valid Loss : 0.501989
# EPOCH : 81 | Train Loss : 0.349775 | Valid Loss : 0.501592
# EPOCH : 82 | Train Loss : 0.346482 | Valid Loss : 0.506332
# EPOCH : 83 | Train Loss : 0.356646 | Valid Loss : 0.502059
# EPOCH : 84 | Train Loss : 0.358166 | Valid Loss : 0.507705
# EPOCH : 85 | Train Loss : 0.354618 | Valid Loss : 0.501050
# EPOCH : 86 | Train Loss : 0.351911 | Valid Loss : 0.503754
# EPOCH : 87 | Train Loss : 0.350726 | Valid Loss : 0.500706
# EPOCH : 88 | Train Loss : 0.349326 | Valid Loss : 0.506731
# EPOCH : 89 | Train Loss : 0.351427 | Valid Loss : 0.507267
# EPOCH : 90 | Train Loss : 0.348606 | Valid Loss : 0.515359
# EPOCH : 91 | Train Loss : 0.342721 | Valid Loss : 0.510897
# EPOCH : 92 | Train Loss : 0.345550 | Valid Loss : 0.503815
# EPOCH : 93 | Train Loss : 0.341151 | Valid Loss : 0.514593
# EPOCH : 94 | Train Loss : 0.342325 | Valid Loss : 0.505494
# EPOCH : 95 | Train Loss : 0.337190 | Valid Loss : 0.500182
# EPOCH : 96 | Train Loss : 0.331953 | Valid Loss : 0.507944
# EPOCH : 97 | Train Loss : 0.332133 | Valid Loss : 0.501908
# EPOCH : 98 | Train Loss : 0.332219 | Valid Loss : 0.504761
# EPOCH : 99 | Train Loss : 0.336126 | Valid Loss : 0.498538
# EPOCH : 100 | Train Loss : 0.327644 | Valid Loss : 0.500439

# %%
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.plot(range(1,n_epochs+1), all_valid_loss, color = "red", label='valid') 
plt.plot(range(1,n_epochs+1), all_train_loss, color = "green", label='train')
plt.legend()

# %% [markdown]
# #### User/item 비교

# %%
train_dataset = MovieLensDataset(train_data, n_item, n_user, IsItem=False)  # u-AutoRec : IsItem=False, i-AutoRec : IsItem=True
test_dataset = MovieLensDataset(test_data, n_item, n_user, IsItem=False)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

# %%
model = AutoRec(n_hidden, n_item, 0.5, custom=False) # n_input을 u-AutoRec : n_item, i-AutoRec : n_user
criterion = nn.MSELoss()
optimizer = Adam(model.parameters(), lr=lr)

# %%
u_all_train_loss = []
u_all_valid_loss = []

for epoch in range(1, n_epochs+1):
    train_loss = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss = eval(model, test_dataloader, criterion, device)

    u_all_train_loss.append(train_loss)
    u_all_valid_loss.append(valid_loss)

    print(f'EPOCH : {epoch:2} | Train Loss : {train_loss:.6f} | Valid Loss : {valid_loss:.6f}')
# Out:
# EPOCH :  1 | Train Loss : 6.535674 | Valid Loss : 3.475558
# EPOCH :  2 | Train Loss : 3.177477 | Valid Loss : 1.594727
# EPOCH :  3 | Train Loss : 1.622581 | Valid Loss : 1.599869
# EPOCH :  4 | Train Loss : 1.627522 | Valid Loss : 1.845854
# EPOCH :  5 | Train Loss : 1.519106 | Valid Loss : 1.664866
# EPOCH :  6 | Train Loss : 1.290507 | Valid Loss : 1.458703
# EPOCH :  7 | Train Loss : 1.152998 | Valid Loss : 1.342310
# EPOCH :  8 | Train Loss : 1.128370 | Valid Loss : 1.291671
# EPOCH :  9 | Train Loss : 1.082734 | Valid Loss : 1.265144
# EPOCH : 10 | Train Loss : 1.046065 | Valid Loss : 1.249657
# EPOCH : 11 | Train Loss : 1.023507 | Valid Loss : 1.246771
# EPOCH : 12 | Train Loss : 1.022998 | Valid Loss : 1.250293
# EPOCH : 13 | Train Loss : 0.994540 | Valid Loss : 1.255960
# EPOCH : 14 | Train Loss : 0.972708 | Valid Loss : 1.257055
# EPOCH : 15 | Train Loss : 0.939959 | Valid Loss : 1.252039
# EPOCH : 16 | Train Loss : 0.937809 | Valid Loss : 1.243119
# EPOCH : 17 | Train Loss : 0.955453 | Valid Loss : 1.235911
# EPOCH : 18 | Train Loss : 0.905124 | Valid Loss : 1.228923
# EPOCH : 19 | Train Loss : 0.891418 | Valid Loss : 1.229269
# EPOCH : 20 | Train Loss : 0.889772 | Valid Loss : 1.232932
# EPOCH : 21 | Train Loss : 0.860179 | Valid Loss : 1.236956
# EPOCH : 22 | Train Loss : 0.868385 | Valid Loss : 1.240363
# EPOCH : 23 | Train Loss : 0.866505 | Valid Loss : 1.243323
# EPOCH : 24 | Train Loss : 0.863174 | Valid Loss : 1.249101
# EPOCH : 25 | Train Loss : 0.849887 | Valid Loss : 1.256876
# EPOCH : 26 | Train Loss : 0.817654 | Valid Loss : 1.264300
# EPOCH : 27 | Train Loss : 0.840011 | Valid Loss : 1.266590
# EPOCH : 28 | Train Loss : 0.853950 | Valid Loss : 1.262071
# EPOCH : 29 | Train Loss : 0.822638 | Valid Loss : 1.258770
# EPOCH : 30 | Train Loss : 0.804947 | Valid Loss : 1.260973
# EPOCH : 31 | Train Loss : 0.811043 | Valid Loss : 1.261967
# EPOCH : 32 | Train Loss : 0.760438 | Valid Loss : 1.267991
# EPOCH : 33 | Train Loss : 0.780623 | Valid Loss : 1.276757
# EPOCH : 34 | Train Loss : 0.759475 | Valid Loss : 1.271351
# EPOCH : 35 | Train Loss : 0.758308 | Valid Loss : 1.265699
# EPOCH : 36 | Train Loss : 0.747567 | Valid Loss : 1.265336
# EPOCH : 37 | Train Loss : 0.717548 | Valid Loss : 1.268663
# EPOCH : 38 | Train Loss : 0.753359 | Valid Loss : 1.284036
# EPOCH : 39 | Train Loss : 0.735829 | Valid Loss : 1.295173
# EPOCH : 40 | Train Loss : 0.725833 | Valid Loss : 1.295559
# EPOCH : 41 | Train Loss : 0.701885 | Valid Loss : 1.286980
# EPOCH : 42 | Train Loss : 0.703810 | Valid Loss : 1.284397
# EPOCH : 43 | Train Loss : 0.689444 | Valid Loss : 1.291839
# EPOCH : 44 | Train Loss : 0.723699 | Valid Loss : 1.302767
# EPOCH : 45 | Train Loss : 0.659131 | Valid Loss : 1.307884
# EPOCH : 46 | Train Loss : 0.685001 | Valid Loss : 1.302906
# EPOCH : 47 | Train Loss : 0.664157 | Valid Loss : 1.291901
# EPOCH : 48 | Train Loss : 0.677141 | Valid Loss : 1.290840
# EPOCH : 49 | Train Loss : 0.670641 | Valid Loss : 1.294109
# EPOCH : 50 | Train Loss : 0.654522 | Valid Loss : 1.303706
# EPOCH : 51 | Train Loss : 0.618467 | Valid Loss : 1.312546
# EPOCH : 52 | Train Loss : 0.638532 | Valid Loss : 1.314355
# EPOCH : 53 | Train Loss : 0.634005 | Valid Loss : 1.306746
# EPOCH : 54 | Train Loss : 0.638426 | Valid Loss : 1.309257
# EPOCH : 55 | Train Loss : 0.632841 | Valid Loss : 1.309950
# EPOCH : 56 | Train Loss : 0.621425 | Valid Loss : 1.308475
# EPOCH : 57 | Train Loss : 0.625137 | Valid Loss : 1.303986
# EPOCH : 58 | Train Loss : 0.615364 | Valid Loss : 1.303833
# EPOCH : 59 | Train Loss : 0.612413 | Valid Loss : 1.312289
# EPOCH : 60 | Train Loss : 0.625334 | Valid Loss : 1.319028
# EPOCH : 61 | Train Loss : 0.592378 | Valid Loss : 1.322483
# EPOCH : 62 | Train Loss : 0.589710 | Valid Loss : 1.324553
# EPOCH : 63 | Train Loss : 0.586975 | Valid Loss : 1.331825
# EPOCH : 64 | Train Loss : 0.638954 | Valid Loss : 1.332002
# EPOCH : 65 | Train Loss : 0.581449 | Valid Loss : 1.328379
# EPOCH : 66 | Train Loss : 0.590891 | Valid Loss : 1.320846
# EPOCH : 67 | Train Loss : 0.586814 | Valid Loss : 1.316529
# EPOCH : 68 | Train Loss : 0.568069 | Valid Loss : 1.323719
# EPOCH : 69 | Train Loss : 0.571358 | Valid Loss : 1.336657
# EPOCH : 70 | Train Loss : 0.535656 | Valid Loss : 1.342765
# EPOCH : 71 | Train Loss : 0.558372 | Valid Loss : 1.339606
# EPOCH : 72 | Train Loss : 0.565406 | Valid Loss : 1.330069
# EPOCH : 73 | Train Loss : 0.592846 | Valid Loss : 1.317425
# EPOCH : 74 | Train Loss : 0.565153 | Valid Loss : 1.304993
# EPOCH : 75 | Train Loss : 0.554224 | Valid Loss : 1.307181
# EPOCH : 76 | Train Loss : 0.540331 | Valid Loss : 1.327498
# EPOCH : 77 | Train Loss : 0.553405 | Valid Loss : 1.347995
# EPOCH : 78 | Train Loss : 0.535323 | Valid Loss : 1.343340
# EPOCH : 79 | Train Loss : 0.541993 | Valid Loss : 1.330707
# EPOCH : 80 | Train Loss : 0.529735 | Valid Loss : 1.318766
# EPOCH : 81 | Train Loss : 0.545811 | Valid Loss : 1.315456
# EPOCH : 82 | Train Loss : 0.525405 | Valid Loss : 1.315013
# EPOCH : 83 | Train Loss : 0.545177 | Valid Loss : 1.321415
# EPOCH : 84 | Train Loss : 0.560656 | Valid Loss : 1.343893
# EPOCH : 85 | Train Loss : 0.510592 | Valid Loss : 1.352175
# EPOCH : 86 | Train Loss : 0.532586 | Valid Loss : 1.337271
# EPOCH : 87 | Train Loss : 0.538456 | Valid Loss : 1.320815
# EPOCH : 88 | Train Loss : 0.515813 | Valid Loss : 1.318549
# EPOCH : 89 | Train Loss : 0.504143 | Valid Loss : 1.327831
# EPOCH : 90 | Train Loss : 0.508214 | Valid Loss : 1.339489
# EPOCH : 91 | Train Loss : 0.517368 | Valid Loss : 1.350061
# EPOCH : 92 | Train Loss : 0.525861 | Valid Loss : 1.344975
# EPOCH : 93 | Train Loss : 0.504011 | Valid Loss : 1.344825
# EPOCH : 94 | Train Loss : 0.515295 | Valid Loss : 1.339364
# EPOCH : 95 | Train Loss : 0.505701 | Valid Loss : 1.335318
# EPOCH : 96 | Train Loss : 0.497897 | Valid Loss : 1.333680
# EPOCH : 97 | Train Loss : 0.520834 | Valid Loss : 1.327248
# EPOCH : 98 | Train Loss : 0.493386 | Valid Loss : 1.335201
# EPOCH : 99 | Train Loss : 0.500582 | Valid Loss : 1.344366
# EPOCH : 100 | Train Loss : 0.505206 | Valid Loss : 1.347740

# %%
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.plot(range(1,n_epochs+1), u_all_valid_loss, color = "red", label='valid') 
plt.plot(range(1,n_epochs+1), u_all_train_loss, color = "green", label='train')
plt.legend()

# %%
plt.xlabel("epoch")
plt.ylabel("Train Loss")
plt.plot(range(1,n_epochs+1), all_train_loss, color = "blue", label='I-AutoRec') 
plt.plot(range(1,n_epochs+1), u_all_train_loss, color = "green", label='U-AutoRec')
plt.ylim(0,5)
plt.legend()

# %%
plt.xlabel("epoch")
plt.ylabel("Valid Loss")
plt.plot(range(1,n_epochs+1), all_valid_loss, color = "blue", label='I-AutoRec') 
plt.plot(range(1,n_epochs+1), u_all_valid_loss, color = "green", label='U-AutoRec')
plt.ylim(0,5)
plt.legend()

# %% [markdown]
# #### MF와 비교

# %%
class MFDataset(Dataset):
    def __init__(self, data: pd.DataFrame):
        self.user = torch.tensor(data.userId.reset_index(drop=True))
        self.item = torch.tensor(data.movieId.reset_index(drop=True))
        self.rating = torch.tensor(data.rating.reset_index(drop=True)).float()
    
    def __len__(self) -> int:
        return (len(self.user))

    def __getitem__(self, idx):
        return self.user[idx], self.item[idx], self.rating[idx]

# %%
class MF(nn.Module):
    def __init__(self, n_user: int, n_item:int, n_factor:int, mu:float):
        super().__init__()
        self.P = nn.Embedding(n_user, n_factor) # user x factor
        self.Q = nn.Embedding(n_item, n_factor) # itme x factor
        self.user_bias = nn.Embedding(n_user, 1) # user x 1
        self.item_bias = nn.Embedding(n_item, 1) # item x 1
        self.mu = mu

    def forward(self, user_id: torch.tensor, item_id: torch.tensor):
        P_u = self.P(user_id) # 1 x factor
        Q_i = self.Q(item_id) # 1 x factor
        b_u = self.user_bias(user_id) # 1x1
        b_i = self.item_bias(item_id) # 1x1

        out = torch.sum(P_u*Q_i, axis=1) + torch.squeeze(b_u) + torch.squeeze(b_i) + self.mu
        return out.view(-1)

# %%
def train(model, dataloader, optimizer, criterion, device):
    model.train()
    train_loss = 0

    for user, item, rating in dataloader:
        user = user.to(device)
        item = item.to(device)
        rating = rating.to(device)
        
        out = model(user, item)
        loss = criterion(out, rating)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    return train_loss / len(dataloader)

def eval(model, dataloader, criterion, device):
    model.eval()
    test_loss = 0

    with torch.no_grad():
        for user, item, rating in dataloader:
            user = user.to(device)
            item = item.to(device)
            rating = rating.to(device)

            out = model(user, item)
            loss = criterion(out, rating)
            test_loss += loss.item()

    return test_loss / len(dataloader)

# %%
#Hyper parameters
device = 'cpu'
n_epochs = 100
batch_size = 256
n_factor = 64
lr = 0.005

# %%
global_mu = np.mean(train_data.rating)
train_dataset = MFDataset(train_data)
test_dataset = MFDataset(test_data)

train_dataloader = DataLoader(train_dataset, batch_size)
test_dataloader = DataLoader(test_dataset, batch_size)

model = MF(n_user, n_item, n_factor, global_mu)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr)

# %%
MF_all_train_loss = []
MF_all_valid_loss = []

for epoch in range(1, n_epochs+1):
    train_loss = train(model, train_dataloader, optimizer, criterion, device)
    valid_loss = eval(model, test_dataloader, criterion, device)

    MF_all_train_loss.append(train_loss)
    MF_all_valid_loss.append(valid_loss)

    print(f'EPOCH : {epoch:2} | Train Loss : {train_loss:.6f} | Valid Loss : {valid_loss:.6f}')
# Out:
# EPOCH :  1 | Train Loss : 52.900732 | Valid Loss : 41.983952
# EPOCH :  2 | Train Loss : 23.360158 | Valid Loss : 29.603502
# EPOCH :  3 | Train Loss : 11.940947 | Valid Loss : 22.861295
# EPOCH :  4 | Train Loss : 6.706358 | Valid Loss : 18.792272
# EPOCH :  5 | Train Loss : 4.069423 | Valid Loss : 16.162724
# EPOCH :  6 | Train Loss : 2.643746 | Valid Loss : 14.355278
# EPOCH :  7 | Train Loss : 1.825602 | Valid Loss : 13.067585
# EPOCH :  8 | Train Loss : 1.332224 | Valid Loss : 12.097825
# EPOCH :  9 | Train Loss : 1.021161 | Valid Loss : 11.363234
# EPOCH : 10 | Train Loss : 0.819988 | Valid Loss : 10.778493
# EPOCH : 11 | Train Loss : 0.688216 | Valid Loss : 10.303593
# EPOCH : 12 | Train Loss : 0.605469 | Valid Loss : 9.908582
# EPOCH : 13 | Train Loss : 0.556640 | Valid Loss : 9.562039
# EPOCH : 14 | Train Loss : 0.537162 | Valid Loss : 9.267809
# EPOCH : 15 | Train Loss : 0.543629 | Valid Loss : 8.950473
# EPOCH : 16 | Train Loss : 0.554540 | Valid Loss : 8.682481
# EPOCH : 17 | Train Loss : 0.559609 | Valid Loss : 8.341390
# EPOCH : 18 | Train Loss : 0.540652 | Valid Loss : 8.079980
# EPOCH : 19 | Train Loss : 0.507548 | Valid Loss : 7.808855
# EPOCH : 20 | Train Loss : 0.475336 | Valid Loss : 7.569266
# EPOCH : 21 | Train Loss : 0.456056 | Valid Loss : 7.349101
# EPOCH : 22 | Train Loss : 0.443304 | Valid Loss : 7.113708
# EPOCH : 23 | Train Loss : 0.435691 | Valid Loss : 6.918159
# EPOCH : 24 | Train Loss : 0.432499 | Valid Loss : 6.686937
# EPOCH : 25 | Train Loss : 0.422502 | Valid Loss : 6.480465
# EPOCH : 26 | Train Loss : 0.410735 | Valid Loss : 6.307385
# EPOCH : 27 | Train Loss : 0.394359 | Valid Loss : 6.061601
# EPOCH : 28 | Train Loss : 0.374843 | Valid Loss : 5.956196
# EPOCH : 29 | Train Loss : 0.360699 | Valid Loss : 5.710538
# EPOCH : 30 | Train Loss : 0.349529 | Valid Loss : 5.619959
# EPOCH : 31 | Train Loss : 0.341038 | Valid Loss : 5.414758
# EPOCH : 32 | Train Loss : 0.334131 | Valid Loss : 5.286980
# EPOCH : 33 | Train Loss : 0.325753 | Valid Loss : 5.120222
# EPOCH : 34 | Train Loss : 0.318300 | Valid Loss : 4.994744
# EPOCH : 35 | Train Loss : 0.308657 | Valid Loss : 4.846779
# EPOCH : 36 | Train Loss : 0.298254 | Valid Loss : 4.722867
# EPOCH : 37 | Train Loss : 0.289175 | Valid Loss : 4.601576
# EPOCH : 38 | Train Loss : 0.280181 | Valid Loss : 4.492929
# EPOCH : 39 | Train Loss : 0.272249 | Valid Loss : 4.363605
# EPOCH : 40 | Train Loss : 0.266608 | Valid Loss : 4.279194
# EPOCH : 41 | Train Loss : 0.261457 | Valid Loss : 4.159236
# EPOCH : 42 | Train Loss : 0.254030 | Valid Loss : 4.064706
# EPOCH : 43 | Train Loss : 0.246918 | Valid Loss : 3.979575
# EPOCH : 44 | Train Loss : 0.240271 | Valid Loss : 3.865746
# EPOCH : 45 | Train Loss : 0.234580 | Valid Loss : 3.797798
# EPOCH : 46 | Train Loss : 0.229991 | Valid Loss : 3.701126
# EPOCH : 47 | Train Loss : 0.223760 | Valid Loss : 3.621169
# EPOCH : 48 | Train Loss : 0.217602 | Valid Loss : 3.552385
# EPOCH : 49 | Train Loss : 0.213031 | Valid Loss : 3.482131
# EPOCH : 50 | Train Loss : 0.208176 | Valid Loss : 3.395648
# EPOCH : 51 | Train Loss : 0.204066 | Valid Loss : 3.328203
# EPOCH : 52 | Train Loss : 0.201215 | Valid Loss : 3.263211
# EPOCH : 53 | Train Loss : 0.196295 | Valid Loss : 3.187124
# EPOCH : 54 | Train Loss : 0.191174 | Valid Loss : 3.133056
# EPOCH : 55 | Train Loss : 0.186749 | Valid Loss : 3.067024
# EPOCH : 56 | Train Loss : 0.183046 | Valid Loss : 3.028704
# EPOCH : 57 | Train Loss : 0.179271 | Valid Loss : 2.953487
# EPOCH : 58 | Train Loss : 0.176404 | Valid Loss : 2.908995
# EPOCH : 59 | Train Loss : 0.172240 | Valid Loss : 2.853870
# EPOCH : 60 | Train Loss : 0.168413 | Valid Loss : 2.809220
# EPOCH : 61 | Train Loss : 0.162425 | Valid Loss : 2.754807
# EPOCH : 62 | Train Loss : 0.158615 | Valid Loss : 2.710461
# EPOCH : 63 | Train Loss : 0.156964 | Valid Loss : 2.667527
# EPOCH : 64 | Train Loss : 0.155684 | Valid Loss : 2.622793
# EPOCH : 65 | Train Loss : 0.152957 | Valid Loss : 2.584464
# EPOCH : 66 | Train Loss : 0.149375 | Valid Loss : 2.548586
# EPOCH : 67 | Train Loss : 0.145269 | Valid Loss : 2.509763
# EPOCH : 68 | Train Loss : 0.142382 | Valid Loss : 2.480649
# EPOCH : 69 | Train Loss : 0.140319 | Valid Loss : 2.433039
# EPOCH : 70 | Train Loss : 0.138787 | Valid Loss : 2.417462
# EPOCH : 71 | Train Loss : 0.137229 | Valid Loss : 2.367646
# EPOCH : 72 | Train Loss : 0.134845 | Valid Loss : 2.335746
# EPOCH : 73 | Train Loss : 0.132019 | Valid Loss : 2.309706
# EPOCH : 74 | Train Loss : 0.128266 | Valid Loss : 2.268599
# EPOCH : 75 | Train Loss : 0.125052 | Valid Loss : 2.251554
# EPOCH : 76 | Train Loss : 0.122280 | Valid Loss : 2.212377
# EPOCH : 77 | Train Loss : 0.121361 | Valid Loss : 2.193513
# EPOCH : 78 | Train Loss : 0.120670 | Valid Loss : 2.162931
# EPOCH : 79 | Train Loss : 0.120469 | Valid Loss : 2.136209
# EPOCH : 80 | Train Loss : 0.118379 | Valid Loss : 2.112100
# EPOCH : 81 | Train Loss : 0.115494 | Valid Loss : 2.079411
# EPOCH : 82 | Train Loss : 0.114098 | Valid Loss : 2.072622
# EPOCH : 83 | Train Loss : 0.112180 | Valid Loss : 2.037047
# EPOCH : 84 | Train Loss : 0.109258 | Valid Loss : 2.014896
# EPOCH : 85 | Train Loss : 0.107720 | Valid Loss : 2.010973
# EPOCH : 86 | Train Loss : 0.106554 | Valid Loss : 1.962501
# EPOCH : 87 | Train Loss : 0.105885 | Valid Loss : 1.965756
# EPOCH : 88 | Train Loss : 0.105195 | Valid Loss : 1.925601
# EPOCH : 89 | Train Loss : 0.103562 | Valid Loss : 1.919600
# EPOCH : 90 | Train Loss : 0.101634 | Valid Loss : 1.892013
# EPOCH : 91 | Train Loss : 0.100009 | Valid Loss : 1.884427
# EPOCH : 92 | Train Loss : 0.099475 | Valid Loss : 1.861983
# EPOCH : 93 | Train Loss : 0.096788 | Valid Loss : 1.838823
# EPOCH : 94 | Train Loss : 0.096316 | Valid Loss : 1.838554
# EPOCH : 95 | Train Loss : 0.096112 | Valid Loss : 1.811776
# EPOCH : 96 | Train Loss : 0.094793 | Valid Loss : 1.797636
# EPOCH : 97 | Train Loss : 0.093236 | Valid Loss : 1.779855
# EPOCH : 98 | Train Loss : 0.091416 | Valid Loss : 1.778436
# EPOCH : 99 | Train Loss : 0.091493 | Valid Loss : 1.745093
# EPOCH : 100 | Train Loss : 0.091718 | Valid Loss : 1.741833

# %%
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.plot(range(1,n_epochs+1), MF_all_valid_loss, color = "red", label='valid') 
plt.plot(range(1,n_epochs+1), MF_all_train_loss, color = "green", label='train')
plt.legend()

# %%
plt.xlabel("epoch")
plt.ylabel("Train Loss")
plt.plot(range(1,n_epochs+1), all_train_loss, color = "blue", label='AutoRec') 
plt.plot(range(1,n_epochs+1), MF_all_train_loss, color = "green", label='MF')
plt.ylim(0,5)
plt.legend()

# %%
plt.xlabel("epoch")
plt.ylabel("Valid Loss")
plt.plot(range(1,n_epochs+1), all_valid_loss, color = "blue", label='AutoRec') 
plt.plot(range(1,n_epochs+1), MF_all_valid_loss, color = "green", label='MF')
# plt.ylim(0,5)
plt.legend()
